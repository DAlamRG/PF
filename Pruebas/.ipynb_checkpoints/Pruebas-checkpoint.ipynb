# %% [markdown]
# # Notebook to plot thermodynamic quantities from data

# %%
# Import neccesary libraries
using DelimitedFiles
using LaTeXStrings
using Plots
using Statistics
pgfplotsx()
# Out:
# Plots.PGFPlotsXBackend()

# %% [markdown]
# ### The following function returns a plot of the desired thermodynamic quantity

# %%
function plt_data_pgf(protein_name::String,model_name::String,geometry::String,qty::String)
    pathname = "/Users/pedroruiz/Desktop/Resultados_sims/"*protein_name*"/"*model_name
   
    pathWL =  pathname*"/WL_"*protein_name*"_"*model_name*"_"*geometry
    pathMET = pathname*"/MET_"*protein_name*"_"*model_name*"_"*geometry
    
    tempsWL = vec(readdlm(pathWL*"/temperatures.csv"))
    tempsMET = vec(readdlm(pathMET*"/thermo_quantities/temperatures.csv"))
    
    if qty == "u"
        
        usWL = vec(readdlm(pathWL*"/us.csv",','))
        up = vec(readdlm(pathMET*"/thermo_quantities/up.csv"))
        uσs = vec(readdlm(pathMET*"/thermo_quantities/uσs.csv"))
        plt = plot(tempsMET,up,lw=1.8,color=RGB{Float64}(0.5,0.4,0.8),alpha=0.95,xlabel=L"T",label=L"\textrm{MET}",ribbon=uσs) 
        plot!(tempsWL,usWL,xlabel=L"T",ylabel=L"\langle E \rangle/N",label=L"\textrm{WL}",lw=2.3,color=RGB{Float64}(0.8,0.2,0.3),alpha=0.8,
        legend=:topleft,xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=13.2,ytickfontsize=13.2,titlefontsize=14)
        return plt
        
    elseif qty == "c"
        
        csWL = vec(readdlm(pathWL*"/cs.csv",','))
        cp = vec(readdlm(pathMET*"/thermo_quantities/cp.csv"))
        cσs = vec(readdlm(pathMET*"/thermo_quantities/cσs.csv"))
        plt = plot(tempsMET,cp,lw=1.8,color=RGB{Float64}(0.5,0.4,0.8),alpha=0.95,xlabel=L"T",label=L"\textrm{MET}",ribbon=cσs,legend=:topright)
        plot!(tempsWL,csWL,xlabel=L"T",ylabel=L"C_{V}/N",label=L"\textrm{WL}",lw=2.2,color=RGB{Float64}(0.8,0.2,0.3),alpha=0.78,
        xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=13.2,ytickfontsize=13.2,titlefontsize=14)
        return plt
        
    elseif qty == "F"
    
        FsWL = vec(readdlm(pathWL*"/Fs.csv",','))
        plt = plot(tempsWL,FsWL,xlabel=L"T",label="",ylabel=L"F/N",lw=3.2,color=RGB{Float64}(0.9,0.4,0.05),alpha=0.7,
        legend=:topright,xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=13.2,ytickfontsize=13.2,
        titlefontsize=14)
        #scatter!(tempsWL3[1:12:400],FsWL3[1:12:400],label="",color=RGB{Float64}(0.9,0.4,0.05),ms=4.5,alpha=0.9)
        return plt
        
        
    elseif qty == "S"
        
        SsWL = vec(readdlm(pathWL*"/Ss.csv",','))
        plt = plot(tempsWL,SsWL,xlabel=L"T",ylabel=L"S/N",label="",lw=3.2,color=RGB{Float64}(0.3,0.9,0.65),alpha=0.7,
        xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=13.2,ytickfontsize=13.2,titlefontsize=14)
        #scatter!(tempsWL4[1:10:400],SsWL3[1:10:400],label="",color=RGB{Float64}(0.2,0.95,0.5),ms=4.5,alpha=0.8)
        return plt
        
        
    end
    
end
# Out:
# plt_data_pgf (generic function with 1 method)

# %%
function plt_data_pgf(protein_name::String,model_name::String,geometry::String,qty::String)
    pathname = "/Volumes/Sims/Resultados_sims/"*protein_name*"/"*model_name
   
    pathWL =  pathname*"/WL_"*protein_name*"_"*model_name*"_"*geometry
    pathMET = pathname*"/MET_"*protein_name*"_"*model_name*"_"*geometry
    
    tempsWL = vec(readdlm(pathWL*"/temperatures.csv"))
    tempsMET = vec(readdlm(pathMET*"/thermo_quantities/temperatures.csv"))
    
    if qty == "u"
        
        usWL = vec(readdlm(pathWL*"/us.csv",','))
        up = vec(readdlm(pathMET*"/thermo_quantities/up.csv"))
        uσs = vec(readdlm(pathMET*"/thermo_quantities/uσs.csv"))
        plt = plot(tempsMET,up,lw=1.8,color=RGB{Float64}(0.5,0.4,0.8),alpha=0.95,xlabel=L"T",label=L"\textrm{MET}",ribbon=uσs) 
        plot!(tempsWL,usWL,xlabel=L"T",ylabel=L"\langle E \rangle/N",label=L"\textrm{WL}",lw=2.3,color=RGB{Float64}(0.8,0.2,0.3),alpha=0.8,
        legend=:topleft,xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=13.2,ytickfontsize=13.2,titlefontsize=14)
        return plt
        
    elseif qty == "c"
        
        csWL = vec(readdlm(pathWL*"/cs.csv",','))
        cp = vec(readdlm(pathMET*"/thermo_quantities/cp.csv"))
        cσs = vec(readdlm(pathMET*"/thermo_quantities/cσs.csv"))
        plt = plot(tempsMET,cp,lw=1.8,color=RGB{Float64}(0.5,0.4,0.8),alpha=0.95,xlabel=L"T",label=L"\textrm{MET}",ribbon=cσs,legend=:topright)
        plot!(tempsWL,csWL,xlabel=L"T",ylabel=L"C_{V}/N",label=L"\textrm{WL}",lw=2.2,color=RGB{Float64}(0.8,0.2,0.3),alpha=0.78,
        xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=13.2,ytickfontsize=13.2,titlefontsize=14)
        return plt
        
    elseif qty == "F"
    
        FsWL = vec(readdlm(pathWL*"/Fs.csv",','))
        plt = plot(tempsWL,FsWL,xlabel=L"T",label="",ylabel=L"F/N",lw=3.2,color=RGB{Float64}(0.9,0.4,0.05),alpha=0.7,
        legend=:topright,xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=13.2,ytickfontsize=13.2,
        titlefontsize=14)
        #scatter!(tempsWL3[1:12:400],FsWL3[1:12:400],label="",color=RGB{Float64}(0.9,0.4,0.05),ms=4.5,alpha=0.9)
        return plt
        
        
    elseif qty == "S"
        
        SsWL = vec(readdlm(pathWL*"/Ss.csv",','))
        plt = plot(tempsWL,SsWL,xlabel=L"T",ylabel=L"S/N",label="",lw=3.2,color=RGB{Float64}(0.3,0.9,0.65),alpha=0.7,
        xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=13.2,ytickfontsize=13.2,titlefontsize=14)
        #scatter!(tempsWL4[1:10:400],SsWL3[1:10:400],label="",color=RGB{Float64}(0.2,0.95,0.5),ms=4.5,alpha=0.8)
        return plt
        
        
    end
    
end
# Out:
# plt_data_pgf (generic function with 1 method)

# %%
plt = plt_data_pgf("chignolin","Full1","triangular","c")
title!(L"\textrm{HPNX/triangular }(d,n)=(3,7)")
#ylims!((-0.02,0.5))
xlims!((-0.005,0.6))

# %%
savefig(plt,"/Volumes/Sims/Resultados_sims/trp_cage/HPNX/c_triangular.pdf")

# %% [markdown]
# ***

# %% [markdown]
# ## Thermalization plots

# %%
function thermal_plt_pgf(protein_name::String,model_name::String,nums)
    pathname = "/Volumes/Sims/Resultados_sims/"*protein_name*"/"*model_name
   
    pathMET1 = pathname*"/MET_"*protein_name*"_"*model_name*"_square/energiesFolder/1_energies.csv"
    pathMET2 = pathname*"/MET_"*protein_name*"_"*model_name*"_triangular/energiesFolder/1_energies.csv"
    pathMET3 = pathname*"/MET_"*protein_name*"_"*model_name*"_fcc/energiesFolder/1_energies.csv"
    
    es1 = vec(readdlm(pathMET1))
    eners1 = es1[1:nums:end]
    rs1 = collect(1:length(es1))[1:nums:end]
    
    es2 = vec(readdlm(pathMET2))
    eners2 = es2[1:nums:end]
    rs2 = collect(1:length(es2))[1:nums:end]
    
    es3 = vec(readdlm(pathMET3))
    eners3 = es3[1:nums:end]
    rs3 = collect(1:length(es3))[1:nums:end]
        
    plt = plot(rs1,eners1,lw=2.0,color=RGB{Float64}(0.6,0.9,0.65),alpha=0.8,xlabel=L"\textrm{Iteraciones}",ylabel=L"E",label=L"\textrm{Cuadrada}",
    xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=12.5,ytickfontsize=13.2,titlefontsize=14,xticks=:scientific,legend=:topright) 
    plot!(rs2,eners2,label=L"\textrm{Triangular}",lw=2.0,color=RGB{Float64}(0.8,0.2,0.3),alpha=0.5)
    plot!(rs3,eners3,label=L"\textrm{fcc}",lw=2.0,alpha=0.65,color=RGB{Float64}(0.5,0.4,0.8))
    return plt
end
# Out:
# thermal_plt_pgf (generic function with 1 method)

# %%
therm = thermal_plt_pgf("chignolin","Full1",6000)
title!(L"\textrm{Full1}")
# Out:
# UndefVarError: thermal_plt_pgf not defined
#
# Stacktrace:
#  [1] top-level scope
#    @ In[14]:1
#  [2] eval
#    @ ./boot.jl:360 [inlined]
#  [3] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1094

# %%
savefig(therm,"/Volumes/Sims/Resultados_sims/chignolin/Full1/thermalization.pdf")

# %% [markdown]
# ***

# %% [markdown]
# ## Plot energies histogram

# %%
function hist_plt_pgf(protein_name::String,model_name::String,geometry::String)
    pathname = "/Volumes/Sims/Resultados_sims/"*protein_name*"/"*model_name
   
    pathMET1 = pathname*"/MET_"*protein_name*"_"*model_name*"_"*geometry*"/energiesFolder/1_energies.csv"
    
    
    es1 = vec(readdlm(pathMET1))
    
    plt = histogram(es1,nbins=100,color="blue",alpha=0.8,xlabel=L"E",ylabel=L"n(E)",label="",
    xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=12.5,ytickfontsize=13.2,titlefontsize=14,xticks=:scientific,legend=:topright,yscale=:log10) 
    
    return plt
end
# Out:
# hist_plt_pgf (generic function with 1 method)

# %%
hist_plt_pgf("chignolin", "HP1", "fcc")

# %% [markdown]
# ***

# %% [markdown]
# ## Microcanonical entropy plots
#
# Plots for
# \begin{equation}
# \log(g(E))
# \end{equation}

# %%
function plt_lgE_pgf(protein_name::String,model_name::String,geometry::String)
    pathname = "/Volumes/Sims/Resultados_sims/"*protein_name*"/"*model_name
   
    pathWL =  pathname*"/WL_"*protein_name*"_"*model_name*"_"*geometry
    
    
    tempsWL = vec(readdlm(pathWL*"/temperatures.csv"))
    lngE_aux  = readdlm(pathWL*"/lngE.csv",',')
    lngE = Dict{Float64,Float64}(lngE_aux[i,1] => lngE_aux[i,2] for i in 1:length(lngE_aux[:,1]))
    ordered = sort(lngE)
    es = Float64[e for e in keys(ordered)]
    ls = Float64[ordered[e] for e in keys(ordered)]

    plt = plot(es, ls, lw = 2.5, color = RGB{Float64}(0.5,0.4,0.8), alpha = 0.95, xlabel=L"E", ylabel=L"\ln(g(E))",label="",
        legend=:topleft, xguidefontsize = 15, yguidefontsize = 15, legendfontsize = 12, xtickfontsize = 13.2, ytickfontsize = 13.2, titlefontsize = 14)
    return plt
        

end
# Out:
# plt_lgE_pgf (generic function with 1 method)

# %%
plt_lgE_pgf("trp_cage","HP1","fcc")

# %% [markdown]
# ## Minimum config plots

# %%
"""
    triangularLattice(nα,nβ)
Returns a matrix with the coordinates for `nα*nβ` points in a triangular lattice.
"""
function triangularLattice(nα,nβ)
    v1 = [1,0]
    v2 = [-1/2,sqrt(3)/2] # Basis vectors for the triangular Bravais lattice.
    
    bM = zeros(Float64,(Int(nα*nβ),2)) # This matrix will contain the linear combinations.
    
    for β in 1:nβ, α in 1:nα
        v = α*v1 + β*v2
        k = α + (β-1)*nα
        bM[k,:] = v
    end
    return bM
end








"""
    chBasisTriangular(m)
Given a matrix `m` whose rows are the coordinates in a regular square lattice; returns the same elements but in the triangular lattice.
"""
function chBasisTriangular(m)
    A = [[-1/2 1];[sqrt(3)/2 0]] # Change of basis matrix.
    mp = zeros(Float64,size(m)) # This array contains the vectors expressed in the new basis.
    for k in 1:size(m)[1]
        el = m[k,:]
        nv = A*el
        mp[k,:] = nv
    end
    return mp
end




"""
   fccLattice(n)  
Given the size of a 3D array `n`; returns a matrix whose rows are the positions on the fcc lattice..
"""
function fccLattice(n)
    a1 = [1,1,0]
    a2 = [0,1,1] 
    a3 = [1,0,1] # Basis vectors for the Bravais lattice (fcc)
    
    fccM = zeros(Float64,(Int(n^3),3)) # This matrix will contain the linear combinations. This is the fcc lattice. 
    # Each entry fccM[i,j,k] represents the site \vec{r}=(i,k,k).
    
    for k in 1:n, j in 1:n, i in 1:n
        v = i*a1 + j*a2 + k*a3
        l = j + (k-1)*n
        s = i + (l-1)*n
        fccM[s,:] = v
    end
    return fccM
end







"""
   fccPositions(N,edo,HPlist)  
Given a 3D array size `N`, a configuration `edo`, and a sequence of aminoacids `HPlist`; returns the configuration in the fcc lattice.
"""
function fccPositions(N,edo,HPlist)
    a1 = [1,1,0]
    a2 = [0,1,1] 
    a3 = [1,0,1] # Basis vectors for the Bravais lattice (fcc)
    
    edofcc = ones(Float64,(length(HPlist),3)) # This matrix will contain the positions in the fcc lattice.

    for w in 1:length(HPlist) # Iterate over the monomers.
        inds = edo[w,:]
        i,j,k = inds # Position in the previous array.
        i = mod1(i,N)
        j = mod1(j,N)
        k = mod1(k,N) # Make the indices periodic.
        v = i*a1 + j*a2 + k*a3
        edofcc[w,:] = v
    end
    return edofcc
end




"""
    color_amin(HPlist)

Given a list of aminoacids `HPlist`, returns a list ofthe corresponding colours. 
"""
function color_amin(HPlist)
    colours = RGB{Float64}[]

    for i in 1:length(HPlist)
        el = HPlist[i]
        if el == 1
            push!(colours,RGB{Float64}(0.5,0.4,0.8))
        elseif el == 2
            push!(colours,RGB{Float64}(0.85,0.2,0.3))
        elseif el == 3
            push!(colours,RGB{Float64}(0.5,0.4,0.8))
        elseif el == 4
            push!(colours,RGB{Float64}(0.6,0.9,0.65))
        elseif el == 5
            push!(colours,RGB{Float64}(0.5,0.6,0.75))
        elseif el == 6
            push!(colours,RGB{Float64}(0.5,0.4,0.8))
        end
    end
    return colours
end




function vis_min(protein_name::String,geometry::String,camarg)
    pathname = "/Volumes/Sims/Resultados_sims/"*protein_name*"/HPNX/WL_"*protein_name*"_HPNX_"*geometry
    
    edo = readdlm(pathname*"/min_edo.csv",',')
    HPlist = vec(readdlm(pathname*"/HPlist.csv"))
    colours = color_amin(HPlist)
    
    N = Int(vec(readdlm(pathname*"/latticesize.csv",','))[1])
    

    if geometry == "square"
        plt = plot(edo[:,2],edo[:,1],lw=2,markershape=:circle,markercolor=colours ,markersize=7,color="purple",label="",xlabel="",
        ylabel="",xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=12.5,ytickfontsize=13.2,titlefontsize=14)
        xlims!((minimum(edo[:,2])-1,maximum(edo[:,2])+1))
        ylims!((minimum(edo[:,1])-1,maximum(edo[:,1])+1))

    
    elseif geometry == "triangular"
        tl = triangularLattice(N,N) # Generate the background lattice
        edo = chBasisTriangular(edo) # Change the basis for the current configuration `edo`.

        plt = scatter(tl[:,1],tl[:,2],color="gray",alpha=0.01,label="",markersize=7,grid=:false,xlabel="",
        ylabel ="",xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=12.5,ytickfontsize=13.2,titlefontsize=14)
        plot!(edo[:,1],edo[:,2],lw=2,markershape=:circle,markercolor=colours ,markersize=8,color="purple",label="",linealpha=0.8)
        xlims!((minimum(edo[:,1])-0.2,maximum(edo[:,1])+0.2))
        ylims!((minimum(edo[:,2])-0.2,maximum(edo[:,2])+0.2))
    
    
    elseif geometry == "fcc"
        #xs = range(-0.5,0.5, length=100)
        #ys = range(-0.5,0.5, length=100)
        
        edo = fccPositions(N,edo,HPlist)
        
        plt = plot(edo[:,1],edo[:,2],edo[:,3],lw=2,markershape=:circle,markercolor=colours,camera = camarg,
        markersize=8,color="purple",label="",grid=:true,xlabel="",ylabel="",zlabel="", xguidefontsize=15,yguidefontsize=15,
        legendfontsize=12,xtickfontsize=13.2,ytickfontsize=13.2,ztickfontsize=13.2,titlefontsize=14,aspect_ratio =:equal)
        #for i in 1:length(HPlist)
         #   surface!(edo[i,1].+xs,edo[i,1].+ys,(x, y)->sqrt(1-(x^2+y^2)) +edo[i,3])
        #end
        xlims!((minimum(edo[:,1])-1,maximum(edo[:,1])+1))
        ylims!((minimum(edo[:,2])-1,maximum(edo[:,2])+1))
        zlims!((minimum(edo[:,3])-1,maximum(edo[:,3])+1))
    end

    return plt

end
# Out:
# vis_min (generic function with 2 methods)

# %%
minplt = vis_min("trp_cage","fcc",(60,15))
title!(L"\textrm{HPNX/triangular}")

# %%
savefig(minplt, "/Volumes/Sims/Resultados_sims/trp_cage/HPNX/minedo_trp_cage.pdf")

# %% [markdown]
# ***
# ***
# ***

# %% [markdown]
# ## Simple exact HP model graphs

# %%
using Plots
using LaTeXStrings
# Out:
# Plots.GRBackend()

# %%
function u(T)
    β = 1/T
    eb = exp(β)
    return - (eb)/(4(4+eb))
end

function c(T)
    β = 1/T
    eb = exp(β)
    a = 4*(β^2)*eb
    b = (4+eb)^2
    return a/(4*b)
end

function S(T)
    β = 1/T
    eb = exp(β)
    a = - (β*eb)/(4+eb)
    b = log(4+eb)
    return a+b
end

function F(T)
    β = 1/T
    eb = exp(β)
    a = (-T)*log(4+eb)
    return a
end
# Out:
# F (generic function with 1 method)

# %%
pgfplotsx()
function pltu(ti,tf,nTs)
    temps = range(ti,stop=tf, length=nTs)
    us = Float64[u(T) for T in temps]
    plt=plot(temps,us,lw=2.8,color=RGB{Float64}(0.8,0.2,0.3),xlabel=L"$T$",ylabel=L"\langle E \rangle/N",label="",title="",
    alpha=0.8,legend=:topleft,xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=13,ytickfontsize=13)
end

function pltc(ti,tf,nTs)
    temps = range(ti,stop=tf, length=nTs)
    cs = Float64[c(T) for T in temps]
    plt=plot(temps,cs,lw=2.8,color=RGB{Float64}(0.6,0.4,0.85),xlabel=L"$T$",ylabel=L"C_{V}/N",label="",title="",
    alpha=0.8,legend=:topleft,xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=13,ytickfontsize=13)
end

function pltS(ti,tf,nTs)
    temps = range(ti,stop=tf, length=nTs)
    Ss = Float64[S(T) for T in temps]
    plt=plot(temps,Ss,lw=2.8,color="purple",xlabel=L"$T$",ylabel=L"$S(T)$",label="",title="",
    alpha=0.65,legend=:topleft,xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=13,ytickfontsize=13)
end

function pltF(ti,tf,nTs)
    temps = range(ti,stop=tf, length=nTs)
    Fs = Float64[F(T) for T in temps]
    plt=plot(temps,Fs,lw=2.8,color="green",xlabel=L"$T$",ylabel=L"$F(T)$",label="",title="",
    alpha=0.65,legend=:topleft,xguidefontsize=15,yguidefontsize=15,legendfontsize=12,xtickfontsize=13,ytickfontsize=13)
end
# Out:
# pltF (generic function with 1 method)

# %%
figt = pltS(0.001,2.0,500)

# %%
savefig(figt,"/Users/pedroruiz/Desktop/tetra_Ss.pdf")
